# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 04
# </h1>

# %%
import random
import pandas as pd
import os

# %% [markdown]
# ### 1.
#
# Q1. Write a Python program to create a list of elements. Shuffle the elements of a given list and display
# the list. [Hint: Use random.shuffle()]
# [10 Marks]

# %%
my_list = [10, 20, 30, 40, 50, 60]

print("Original List:", my_list)

random.shuffle(my_list)

print("Shuffled List:", my_list)
# Out:
# Original List: [10, 20, 30, 40, 50, 60]
# Shuffled List: [10, 50, 40, 30, 60, 20]

# %% [markdown]
# ## Q2. DataFrame (Stationery Data)
#
# Create the following **DataFrame named `data`**. Write the Python code for the following commands.
#
# | Item   | Company | Count | Price |
# | ------ | ------- | ----- | ----- |
# | Pencil | Apsara  | 15    | 250   |
# | Pencil | Natraj  | 20    | 200   |
# | Pen    | Cello   | 25    | 600   |
# | Pen    | Parkar  | 35    | 900   |
# | Eraser | Apsara  | 20    | 300   |
#
# ### Questions
#
# a) Find all rows with the label **“Pencil”** and extract **all columns**.
#
# b) Change the **Eraser count to 25 instead of 20**.
#
# c) List only the columns **Company** and **Price**.
#
# d) List only rows with labels **“Pencil”** and **“Pen”**.
#
# e) Rename column **Count** as **Quantity** and display the DataFrame.
#
# **[20 Marks]**

# %%
# Q2 - DataFrame operations
data = {
    'Company': ['Apsara', 'Natraj', 'Cello', 'Parkar', 'Apsara'],
    'Count': [15, 20, 25, 35, 20],
    'Price': [250, 200, 600, 900, 300]
}

index_labels = ['Pencil', 'Pencil', 'Pen', 'Pen', 'Eraser']

df = pd.DataFrame(data, index=index_labels)

print("Original DataFrame:")
print(df)

print("\na) Find all rows with the label 'Pencil':")
print(df.loc['Pencil'])

print("\nb) Change the Eraser count as 25 instead of 20:")
df.loc['Eraser', 'Count'] = 25
print(df)

print("\nc) List only the columns Company and Price:")
print(df[['Company', 'Price']])

print("\nd) List only rows with labels 'Pencil' and 'Pen':")
print(df.loc[['Pencil', 'Pen']])

print("\ne) Rename Column Count as Quantity:")
df.rename(columns={'Count': 'Quantity'}, inplace=True)
print(df)

# OR Q2 - File operations with friends
filename = "friends.txt"

print("\na) Creating file with 5 friends...")
with open(filename, 'w') as f:
    f.write("Alice\n")
    f.write("Bob\n")
    f.write("Charlie\n")
    f.write("David\n")
    f.write("Eve\n")

print("b) Display contents of file:")
with open(filename, 'r') as f:
    print(f.read())

print("c) Appending other 5 friends...")
with open(filename, 'a') as f:
    f.write("Frank\n")
    f.write("Grace\n")
    f.write("Hank\n")
    f.write("Ivy\n")
    f.write("Jack\n")

print("d) Display modified file contents:")
with open(filename, 'r') as f:
    print(f.read())

if os.path.exists(filename):
    os.remove(filename)
# Out:
# Original DataFrame:
#        Company  Count  Price
# Pencil  Apsara     15    250
# Pencil  Natraj     20    200
# Pen      Cello     25    600
# Pen     Parkar     35    900
# Eraser  Apsara     20    300
#
# a) Find all rows with the label 'Pencil':
#        Company  Count  Price
# Pencil  Apsara     15    250
# Pencil  Natraj     20    200
#
# b) Change the Eraser count as 25 instead of 20:
#        Company  Count  Price
# Pencil  Apsara     15    250
# Pencil  Natraj     20    200
# Pen      Cello     25    600
# Pen     Parkar     35    900
# Eraser  Apsara     25    300
#
# c) List only the columns Company and Price:
#        Company  Price
# Pencil  Apsara    250
# Pencil  Natraj    200
# Pen      Cello    600
# Pen     Parkar    900
# Eraser  Apsara    300
#
# d) List only rows with labels 'Pencil' and 'Pen':
#        Company  Count  Price
# Pencil  Apsara     15    250
# Pencil  Natraj     20    200
# Pen      Cello     25    600
# Pen     Parkar     35    900
#
# e) Rename Column Count as Quantity:
#        Company  Quantity  Price
# Pencil  Apsara        15    250
# Pencil  Natraj        20    200
# Pen      Cello        25    600
# Pen     Parkar        35    900
# Eraser  Apsara        25    300
#
# a) Creating file with 5 friends...
# b) Display contents of file:
# Alice
# Bob
# Charlie
# David
# Eve
#
# c) Appending other 5 friends...
# d) Display modified file contents:
# Alice
# Bob
# Charlie
# David
# Eve
# Frank
# Grace
# Hank
# Ivy
# Jack

# %% [markdown]
# ## OR
#
# OR
#
# Q2. Write a python program for following
# a) Create a file which stores the first name, middle name and last name of your 5 friends
# b) Display contents of file
# c) Append other 5 friend’s names
# d) Display modified file contents

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
