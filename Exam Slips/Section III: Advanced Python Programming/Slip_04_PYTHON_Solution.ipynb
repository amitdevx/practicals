# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 04
# </h1>

# %%
import random
import pandas as pd
import os

# %% [markdown]
# ### 1.
#
# Q1. Write a Python program to create a list of elements. Shuffle the elements of a given list and display
# the list. [Hint: Use random.shuffle()]
# [10 Marks]

# %%
my_list = [10, 20, 30, 40, 50, 60]

print("Original List:", my_list)

random.shuffle(my_list)

print("Shuffled List:", my_list)

data = {
    'Company': ['Apsara', 'Natraj', 'Cello', 'Parkar', 'Apsara'],
    'Count': [15, 20, 25, 35, 20],
    'Price': [250, 200, 600, 900, 300]
}

index_labels = ['Pencil', 'Pencil', 'Pen', 'Pen', 'Eraser']

print("Original DataFrame:")

print(df)

print("\na) Find all rows with the label 'Pencil':")

print(df.loc['Pencil'])

print("\nb) Change the Eraser count as 25 instead of 20:")

print(df)

print("\nc) List only the columns Company and Price:")

print(df[['Company', 'Price']])

print("\nd) List only rows with labels 'Pencil' and 'Pen':")

print(df.loc[['Pencil', 'Pen']])

print("\ne) Rename Column Count as Quantity:")

print(df)

print("a) Creating file with 5 friends...")

print("b) Display contents of file:")

with open(filename, 'r') as f:
    print(f.read())

print("c) Appending other 5 friends...")

print("d) Display modified file contents:")

with open(filename, 'r') as f:
    print(f.read())
# Out:
# Original List: [10, 20, 30, 40, 50, 60]
# Shuffled List: [40, 20, 60, 10, 30, 50]
# Original DataFrame:
#        Company  Quantity  Price
# Pencil  Apsara        15    250
# Pencil  Natraj        20    200
# Pen      Cello        25    600
# Pen     Parkar        35    900
# Eraser  Apsara        25    300
#
# a) Find all rows with the label 'Pencil':
#        Company  Quantity  Price
# Pencil  Apsara        15    250
# Pencil  Natraj        20    200
#
# b) Change the Eraser count as 25 instead of 20:
#        Company  Quantity  Price
# Pencil  Apsara        15    250
# Pencil  Natraj        20    200
# Pen      Cello        25    600
# Pen     Parkar        35    900
# Eraser  Apsara        25    300
#
# c) List only the columns Company and Price:
#        Company  Price
# Pencil  Apsara    250
# Pencil  Natraj    200
# Pen      Cello    600
# Pen     Parkar    900
# Eraser  Apsara    300
#
# d) List only rows with labels 'Pencil' and 'Pen':
#        Company  Quantity  Price
# Pencil  Apsara        15    250
# Pencil  Natraj        20    200
# Pen      Cello        25    600
# Pen     Parkar        35    900
#
# e) Rename Column Count as Quantity:
#        Company  Quantity  Price
# Pencil  Apsara        15    250
# Pencil  Natraj        20    200
# Pen      Cello        25    600
# Pen     Parkar        35    900
# Eraser  Apsara        25    300
# a) Creating file with 5 friends...
# b) Display contents of file:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 45
#      41 print("a) Creating file with 5 friends...")
#      43 print("b) Display contents of file:")
# ---> 45 with open(filename, 'r') as f:
#      46     print(f.read())
#      48 print("c) Appending other 5 friends...")
#
# File ~/jupyter-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'friends.txt'

# %% [markdown]
# Q2. Create a following DataFrame named as “data”. Write the python code for the following
# commands.
# Company
#
# Count
#
# Price
#
# Pencil
#
# Apsara
#
# 15
#
# 250
#
# Pencil
#
# Natraj
#
# 20
#
# 200
#
# Pen
#
# Cello
#
# 25
#
# 600
#
# Pen
#
# Parkar
#
# 35
#
# 900
#
# Eraser
#
# Apsara
#
# 20
#
# 300
#
# a) Find all rows with the label “Pencil”. Extract all columns
# b) Change the Eraser count as 25 instead of 20.
# c) List only the columns Company and Price.
# d) List only rows with labels ‘Pencil’ and ‘Pen’
# e) Rename Column Count as Quantity and display DataFrame.
# [20 Marks]

# %%
df = pd.DataFrame(data, index=index_labels)

df.loc['Eraser', 'Count'] = 25

df.rename(columns={'Count': 'Quantity'}, inplace=True)

filename = "friends.txt"

with open(filename, 'w') as f:
    f.write("Alice\n")
    f.write("Bob\n")
    f.write("Charlie\n")
    f.write("David\n")
    f.write("Eve\n")

with open(filename, 'a') as f:
    f.write("Frank\n")
    f.write("Grace\n")
    f.write("Hank\n")
    f.write("Ivy\n")
    f.write("Jack\n")

if os.path.exists(filename):
    os.remove(filename)

# %% [markdown]
# ## OR
#
# OR
#
# Q2. Write a python program for following
# a) Create a file which stores the first name, middle name and last name of your 5 friends
# b) Display contents of file
# c) Append other 5 friend’s names
# d) Display modified file contents

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
