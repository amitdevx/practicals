# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 01
# </h1>

# %%
import os
import pandas as pd
import sys
import glob

# %% [markdown]
# ### 1.
#
# Q1. Write Python code to create a dictionary containing mobile names and their prices. Create
# DataFrame from this dictionary. Display the contents of DataFrame.
# [10 Marks]

# %%
data = {
    'Mobile': ['iPhone 13', 'Samsung S21', 'Pixel 6', 'OnePlus 9'],
    'Price': [79900, 69999, 59999, 49999]
}

print("Mobile Data DataFrame:")

print(df)

print("Available Car Models:", cars.available_models())
    print("Available Bike Models:", bikes.available_models())
except ImportError as e:
    print(f"Error importing package: {e}")
    print("Please ensure the 'vehicle' package is created correctly.")

files = os.listdir(current_dir)

print("All files in current directory:", files)

print("Total count of .py files:", len(py_files))

if py_files:
    print(f"\nContent of {py_files[0]}:")
    with open(py_files[0], 'r') as f:
        print(f.read())
else:
    print("No .py files found to display content.")

# %% [markdown]
# Q2. Create a package vehicle with a sub package types, sub package type contains modules cars and
# bikes. Each module should have a function available_models() returning a list of models. Write a
# python program to display all available models of cars and bikes.
# [20 Marks]

# %%
df = pd.DataFrame(data)

base_dir = "vehicle"

types_dir = os.path.join(base_dir, "types")

os.makedirs(types_dir, exist_ok=True)

open(os.path.join(base_dir, "__init__.py"), 'w').close()

open(os.path.join(types_dir, "__init__.py"), 'w').close()

with open(os.path.join(types_dir, "cars.py"), "w") as f:
    f.write("def available_models():\n    return ['Sedan', 'SUV', 'Hatchback']")

with open(os.path.join(types_dir, "bikes.py"), "w") as f:
    f.write("def available_models():\n    return ['Sports', 'Cruiser', 'Street']")

sys.path.append(os.getcwd())

# %% [markdown]
# ## OR
#
# OR
#
# Q2. Write a python program to list all files in a current directory. Display total count of .py files and
# content of any one .py files.

# %%
try:
    from vehicle.types import cars, bikes

current_dir = "."

py_files = [f for f in files if f.endswith('.py')]

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
