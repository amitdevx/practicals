# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 09
# </h1>

# %%
import pandas as pd

# %% [markdown]
# ## Q1. Write a python program to accepts a value of n and create a generator that yields even numbers up
# to n.
# [10 Marks]

# %%
# Q1 OR: Even number generator
def even_generator(n):
    for i in range(2, 2*n+1, 2):
        yield i

try:
    n = int(input("Enter n for even numbers generator: "))
except Exception:
    n = 10
    print(f"Input: n={n}")

print(f"First {n} even numbers:")
for num in even_generator(n):
    print(num, end=' ')
print()

# %% [markdown]
# ## Q2. Write a python program for following a) Create DataFrames Student 1, Student 2 and display contents
# b) Join the two DataFrames in third frame with matching records from both sides.
# c) Display Third DataFrame.
# Student 1
#
# Student 2
# ID
#
# City
#
# Marks
#
# 0
#
# S2
#
# Pune
#
# 97
#
# 23
#
# 1
#
# S4
#
# Nashik
#
# 78
#
# Om
#
# 20
#
# 2
#
# S5
#
# Mumbai
#
# 86
#
# S4
#
# Raj
#
# 21
#
# 3
#
# S6
#
# Delhi
#
# 66
#
# S5
#
# Kanika
#
# 20
#
# 4
#
# S7
#
# Nanded
#
# 54
#
# ID
#
# Name
#
# Age
#
# 0
#
# S1
#
# Anita
#
# 18
#
# 1
#
# S2
#
# Sakshi
#
# 2
#
# S3
#
# 3
# 4
#
# [20 Marks]

# %%
# Q2: DataFrames Student 1, Student 2 - merge
df1 = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5],
    'City': ['Pune', 'Nashik', 'Mumbai', 'Delhi', 'Nanded'],
    'Marks': [97, 78, 86, 66, 54]
})

df2 = pd.DataFrame({
    'ID': [1, 2, 3, 6, 7],
    'Name': ['Amit', 'Bob', 'Charlie', 'Dave', 'Eve'],
    'Age': [20, 21, 22, 23, 24]
})

df3 = pd.merge(df1, df2, on='ID', how='inner')

print("DataFrame Student 1:")
print(df1)
print("\nDataFrame Student 2:")
print(df2)
print("\nMerged DataFrame (Inner Join on ID):")
print(df3)
# Out:
# DataFrame Student 1:
#    ID    City  Marks
# 0   1    Pune     97
# 1   2  Nashik     78
# 2   3  Mumbai     86
# 3   4   Delhi     66
# 4   5  Nanded     54
#
# DataFrame Student 2:
#    ID     Name  Age
# 0   1     Amit   20
# 1   2      Bob   21
# 2   3  Charlie   22
# 3   6     Dave   23
# 4   7      Eve   24
#
# Merged DataFrame (Inner Join on ID):
#    ID    City  Marks     Name  Age
# 0   1    Pune     97     Amit   20
# 1   2  Nashik     78      Bob   21
# 2   3  Mumbai     86  Charlie   22

# %% [markdown]
# ## OR
#
# ## Q2. Write a python program using user define function to accept a number and perform the following
# task:
# a) Check number is Armstrong or not.
# b) Calculate and display sum of digits till single digit [e.g. - 558 = 18 = 9]

# %%
# Q2 OR: Check number type
try:
    num = int(input("Enter a number: "))
except Exception:
    num = -7
    print(f"Input: {num}")

if num > 0:
    print(f"{num} is Positive")
elif num < 0:
    print(f"{num} is Negative")
else:
    print(f"{num} is Zero")

# %% [markdown]
# ## Q3. Viva
#
# [5 Marks]
