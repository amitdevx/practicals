# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 12
# </h1>

# %%
import pandas as pd
import time
from datetime import datetime
import random

# %% [markdown]
# ### 1.
#
# Q1. Create a data.csv file containing employee name, designation, salary of an employee. Write a
# python program to create a DataFrame using data.csv and display the contents of DataFrame with
# statistical information of dataframe.
# [10 Marks]

# %%
filename = "data.csv"

with open(filename, 'w') as f:
    f.write("Name,Designation,Salary\n")
    f.write("Alice,Manager,75000\n")
    f.write("Bob,Developer,60000\n")
    f.write("Charlie,Designer,55000\n")
    f.write("David,Developer,62000\n")
    f.write("Eve,HR,50000\n")

print(f"{filename} created.")

print("\nDataFrame Content:")

print(df)

print("\nStatistical Information:")

print(df.describe())

print("Local Time (struct_time):", local_time)

print("UTC Time (struct_time):", utc_time)

print("Current Time (ctime):", time.ctime())

print("UTC Time (asctime(gmtime)):", time.asctime(time.gmtime()))

date_str = input("Enter date-time (DD-MM-YYYY HH:MM:SS): ")

try:
    dt_obj = datetime.strptime(date_str, "%d-%m-%Y %H:%M:%S")
    print("Parsed datetime object:", dt_obj)

print(f"Format 1: {fmt1}")
    print(f"Format 2: {fmt2}")

except ValueError:
    print("Invalid date format. Please use DD-MM-YYYY HH:MM:SS")

my_list = [10, 20, 30, 40, 50]

my_tuple = (1, 2, 3, 4, 5)

print("Random from list:", random.sample(my_list, 2))

print("Random from string:", random.sample(my_string, 3))

print("Random from tuple:", random.sample(my_tuple, 2))

# %% [markdown]
# Q2. Write a Python program that:
# a) Retrieves current local time and UTC time.
# b) Prints the current time using ctime() and gmtime().
# c) Accepts a date-time string input in the format DD-MM-YYYY HH:MM:SS.
# d) Parses the string using strptime() and formats it back using strftime() and display it in two
# custom formats.
# [20 Marks]

# %%
df = pd.DataFrame(pd.read_csv(filename))

local_time = time.localtime()

utc_time = time.gmtime()

fmt1 = dt_obj.strftime("%Y-%m-%d %I:%M %p")
    fmt2 = dt_obj.strftime("%A, %d %B %Y")

my_string = "HelloPython"

# %% [markdown]
# ## OR
#
# OR
#
# Q2. Write a python program to create a list, string and tuple in python. Apply random module to display
# unique multiple random elements from above created sequence type.

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
