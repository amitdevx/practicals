# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 20
# </h1>

# %%
import pandas as pd
import os
import sys

# %% [markdown]
# ### 1.
#
# Q1. Create a DataFrame from a dictionary {Subject_Name : Marks} and display the first 5 rows and
#     last 5 rows of DataFrame.
#                                                                                                [10 Marks]

# %%
with open(os.path.join(base_dir, "account.py"), "w") as f:
            f.write("def open_account(name):\n    print(f'Account created successfully for user: {name}')")

with open(os.path.join(base_dir, "loan.py"), "w") as f:
            f.write("def apply_loan(amount):\n    print(f'Loan application for amount {amount} submitted successfully.')")

print(f"Package 'banking' created at {os.path.abspath(base_dir)}")
    else:
        print("Package 'banking' already exists.")

print("Full DataFrame (first 5 and last 5 rows shown below):")

print(df)

print("\nFirst 5 rows:")

print(df.head(5))

print("\nLast 5 rows:")

print(df.tail(5))

print(f"Created dummy file '{filename}'.")

try:
    fname = input("Enter filename (default: stats_test.txt): ")
    if not fname: fname = filename

print("\nFile Content:")
        print(content)

print(f"\nTotal Characters: {chars}")
        print(f"Total Words: {len(words)}")
        print(f"Total Lines: {len(lines)}")
    else:
        print("File does not exist.")

except ImportError as e:
    print(f"Error importing package: {e}")

# %% [markdown]
# Q2. Write a Python program that accepts a filename from the user, opens the file in read mode and
#     display the contents of files. The program should compute and display the total number of
#     characters (including spaces), words, and lines present in the file. If file does not exist give
#     appropriate message.
#
#                                                                                                [20 Marks]

# %%
def create_banking_package():
    base_dir = "banking"
    if not os.path.exists(base_dir):
        os.makedirs(base_dir)
        open(os.path.join(base_dir, "__init__.py"), 'a').close()

data = {'Subject_Name': ['Math', 'Physics', 'Chemistry', 'Biology', 'English', 
                         'History', 'Geography', 'CS', 'Economics', 'Civics',
                         'Music', 'Art', 'PE', 'Hindi', 'Marathi']}

marks = [85, 90, 78, 92, 88, 76, 82, 95, 80, 75, 88, 90, 85, 82, 79]

df = pd.DataFrame({'Subject_Name': data['Subject_Name'], 'Marks': marks})

filename = "stats_test.txt"

with open(filename, "w") as f:
    f.write("Line 1: Hello World\nLine 2: Python Programming\nLine 3: Data Science")

if os.path.exists(fname):
        with open(fname, 'r') as f:
            content = f.read()

lines = content.splitlines()
        words = content.split()
        chars = len(content) # Including spaces and newlines? Yes "including spaces"

# %% [markdown]
# ## OR
#
# OR
#
#
# Q2. Create a package banking with modules account.py and loan.py.
#     a) account.py should contain function open_account(name) that accepts a user’s name and prints a
#     message confirming account creation.
#     b) loan.py should contain function apply_loan(amount) that accepts a loan amount and prints a confirmation
#     message with the amount.
#     Write a python program to import modules from banking package and demonstrate both functions.

# %%
except Exception as e:
    print(f"Error: {e}")

if os.path.exists(filename):
    os.remove(filename)

create_banking_package()

sys.path.append(os.getcwd())

try:
    from banking import account, loan

account.open_account("John Doe")
    loan.apply_loan(50000)

# %% [markdown]
# Q3. Viva                                                                                       [5 Marks]
