# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 27
# </h1>

# %% [markdown]
# ### 1.
#
# Q1. Write a Python program using regular expressions to validate whether a given string matches the
#     pattern of three-letter words such as cat, cot, cut, mat, met, mud.
#                                                                                             [10 Marks]

# %%
import time
from datetime import datetime

try:
    text = input("Enter a string: ")
except EOFError:
    text = "Samidha"
    print(f"Input: {text}")

modified_text = text.replace('a', '*')

print(f"Modified String: {modified_text}")

try:
    n_str = input("Enter number of students: ")
    if not n_str: n_str = "3"
    n = int(n_str)

for i in range(n):
        marks_str = input(f"Enter marks for Student {i+1}: ")
        if not marks_str: marks_str = "45"
        marks = float(marks_str)

status = check_pass_fail(marks)
        print(f"Result: {status}")

print(f"\nTotal Passed: {passed}")
    print(f"Total Failed: {failed}")

except ValueError:
    print("Invalid input.")

print(f"Current Time (ctime): {time.ctime()}")

print(f"Current UTC Time (gmtime): {time.strftime('%a %b %d %H:%M:%S %Y', utc_time)}")

try:
    dt_str = input("Enter date-time (DD-MM-YYYY HH:MM:SS): ")
    if not dt_str: dt_str = "25-12-2023 15:30:00"

print(f"Parsed: {dt_obj}")
    print(f"Format 1: {fmt1}")
    print(f"Format 2: {fmt2}")

except ValueError as e:
    print(f"Error: {e}")

# %% [markdown]
# Q2. Build a package education with a sub package courses, containing modules science.py and
#
#     arts.py. Each module should have a function get_subjects(). Write a python program to display all
#     subjects.
#                                                                                             [20 Marks]

# %%
def check_pass_fail(marks):
    return "Pass" if marks >= 40 else "Fail"

passed = 0
    failed = 0

if status == "Pass":
            passed += 1
        else:
            failed += 1

local_time = time.localtime()

utc_time = time.gmtime()

dt_obj = datetime.strptime(dt_str, "%d-%m-%Y %H:%M:%S")

fmt1 = dt_obj.strftime("%Y-%m-%d %I:%M %p")
    fmt2 = dt_obj.strftime("%A, %d %B %Y")

# %% [markdown]
# ## OR
#
# OR
#
#
# Q2. Write a python program to display all entries in a current directory and identify each as file or
#     folder. [Use getcwd() function to retrieve current directory]

# %% [markdown]
# Q3. Viva                                                                                    [5 Marks]
