# %% [markdown]
# # Slip 06 - Advanced Python Programming

# %% [markdown]
# Q1. Write a Python program that prompts the user to input two numbers and raises a TypeError exception if the inputs are not numerical.
# [10 Marks]

# %%
try:
    num1 = input('Enter first number: ')
    num2 = input('Enter second number: ')
except Exception:
    num1, num2 = '10', '5'
    print(f"Input: {num1}, {num2}")

try:
    num1 = float(num1)
    num2 = float(num2)
    print(f'Numbers: {num1}, {num2}')
    print(f'Sum: {num1 + num2}')
    print(f'Difference: {num1 - num2}')
    print(f'Product: {num1 * num2}')
    if num2 != 0:
        print(f'Division: {num1 / num2}')
except ValueError:
    print('Error: Inputs must be numerical values')

# %% [markdown]
# Q2. Create a DataFrame with Company, Count, Price columns and perform operations.
# [20 Marks]
# a) Find all rows with label 'Pencil'
# b) Change Eraser count from 20 to 25
# c) List Company and Price columns
# d) List rows with 'Pencil' and 'Pen'
# e) Delete Count column

# %%
import pandas as pd
data = pd.DataFrame({
    'Company': ['Apsara', 'Natraj', 'Cello', 'Parker', 'Apsara'],
    'Type': ['Pencil', 'Pencil', 'Pen', 'Pen', 'Eraser'],
    'Count': [15, 20, 25, 35, 20],
    'Price': [250, 200, 600, 900, 300]
})
print('Original DataFrame:')
print(data)
print('\nPencil rows:')
print(data[data['Type'] == 'Pencil'])
data.loc[data['Type'] == 'Eraser', 'Count'] = 25
print('\nAfter updating Eraser count:')
print(data[['Company', 'Price']])
data_dropped = data.drop('Count', axis=1)
print('\nAfter deleting Count column:')
print(data_dropped)
# Out:
# Original DataFrame:
#   Company    Type  Count  Price
# 0  Apsara  Pencil     15    250
# 1  Natraj  Pencil     20    200
# 2   Cello     Pen     25    600
# 3  Parker     Pen     35    900
# 4  Apsara  Eraser     20    300
#
# Pencil rows:
#   Company    Type  Count  Price
# 0  Apsara  Pencil     15    250
# 1  Natraj  Pencil     20    200
#
# After updating Eraser count:
#   Company  Price
# 0  Apsara    250
# 1  Natraj    200
# 2   Cello    600
# 3  Parker    900
# 4  Apsara    300
#
# After deleting Count column:
#   Company    Type  Price
# 0  Apsara  Pencil    250
# 1  Natraj  Pencil    200
# 2   Cello     Pen    600
# 3  Parker     Pen    900
# 4  Apsara  Eraser    300

# %% [markdown]
# ### OR

# %% [markdown]
# Q2 (OR). Create a Flask web page for your Personal Portfolio.
# [20 Marks]
# a) Show name as centered heading
# b) List Qualification details
# c) Add special skills in scrolling

# %% [markdown]
# **Note:** This Flask application cannot run inside a Jupyter notebook.
#
# See the complete Flask project in the [`slip_06/`](slip_06/) folder:
# - **Q1 (main):** [`slip_06/slip_06_Q1/`](slip_06/slip_06_Q1/)
# - **Q2 (OR):** [`slip_06/slip_06_Q2/`](slip_06/slip_06_Q2/)
#
# To run: `cd slip_06/slip_06_Q2/Q2 && python Q06_app2.py`

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
#
# Viva Voce / 5 Marks.
