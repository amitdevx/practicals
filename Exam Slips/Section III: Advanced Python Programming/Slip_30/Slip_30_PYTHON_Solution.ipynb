# %% [markdown]
# # Slip 30 - Advanced Python Programming

# %% [markdown]
# Q1. [10 Marks]

# %%
print('Q1 Solution')

# %% [markdown]
# Q2. [20 Marks]

# %%
print('Q2 Solution')

# %% [markdown]
# ### OR

# %% [markdown]
# Q2 (OR). [20 Marks]

# %%
print('Q2 OR Solution')

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
#
# Viva Voce / 5 Marks.
