# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 13
# </h1>

# %%
import time
import os
import pandas as pd

# %% [markdown]
# ### 1.
#
# Q1.Write a Python program to get the current time and demonstrate the following functions from the
# time module:
# a) Convert the current time in seconds to a readable string
# b) Converts time in seconds to a struct_time in UTC
# [10 Marks]

# %%
current_seconds = time.time()

print(f"Current time in seconds: {current_seconds}")

readable_string = time.ctime(current_seconds)

print(f"Readable string (ctime): {readable_string}")

utc_struct = time.gmtime(current_seconds)

print(f"UTC struct_time (gmtime): {utc_struct}")

filename = input("Enter filename to read: ")

if os.path.exists(filename):
    try:
        with open(filename, 'r') as f:
            print(f"Reading {filename} line by line:")

for line in f:
                print(line.strip()) # strip newline for cleaner output
                print(f"Current file pointer position (ftell): {f.tell()}")

print("\nMoving file pointer back to beginning (seek(0))...")
            f.seek(0)

print("Displaying file content again:")
            content = f.read()
            print(content)

print("DataFrame Student 1:")

print(df1)

print("\nDataFrame Student 2:")

print(df2)

print("\nMerged DataFrame (Inner Join on ID):")

print(df3)

# %% [markdown]
# Q2. Write a Python program that prompts the user to enter a text file name. If the file exists, open it in
# read mode, display its contents line by line, and show the current file pointer position after each
# line using ftell(). Then move the file pointer back to the beginning using seek() and display the file
# content again. If the file does not exist, display an appropriate error message.
# [20 Marks]

# %%
df1 = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5],
    'City': ['Pune', 'Nashik', 'Mumbai', 'Delhi', 'Nanded'],
    'Marks': [97, 78, 86, 66, 54]
})

df2 = pd.DataFrame({
    'ID': [1, 2, 3, 6, 7],
    'Name': ['Amit', 'Bob', 'Charlie', 'Dave', 'Eve'],
    'Age': [20, 21, 22, 23, 24]
})

# %% [markdown]
# ## OR
#
# OR
# Q2. Write a python program for following a) Create DataFrames Student 1, Student 2 and display contents
# b) Join the two DataFrames in third frame with matching records from both sides.
# c) Display Content of Third DataFrame.
# Student 1
#
# Student 2
# ID
#
# City
#
# Marks
#
# 0
#
# S2
#
# Pune
#
# 97
#
# 23
#
# 1
#
# S4
#
# Nashik
#
# 78
#
# Om
#
# 20
#
# 2
#
# S5
#
# Mumbai
#
# 86
#
# S4
#
# Raj
#
# 21
#
# 3
#
# S6
#
# Delhi
#
# 66
#
# S5
#
# Kanika
#
# 20
#
# 4
#
# S7
#
# Nanded
#
# 54
#
# ID
#
# Name
#
# Age
#
# 0
#
# S1
#
# Anita
#
# 18
#
# 1
#
# S2
#
# Sakshi
#
# 2
#
# S3
#
# 3
# 4

# %%
except Exception as e:
        print(f"Error reading file: {e}")
else:
    print("File does not exist.")

df3 = pd.merge(df1, df2, on='ID', how='inner')

# %% [markdown]
# Q3. Viva
#
# [5 Marks]
