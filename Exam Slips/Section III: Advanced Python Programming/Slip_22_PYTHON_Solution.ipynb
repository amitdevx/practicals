# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 22
# </h1>

# %%
import pandas as pd
import math

# %% [markdown]
# ### 1.
#
# Q1. Write a Python program that accepts value of m and n. Divides m by n and handles a
#      ZeroDivisionError if the user tries to divide by zero.
#                                                                                                 [10 Marks]

# %%
try:
    m_str = input("Enter numerator (m): ")
    n_str = input("Enter denominator (n): ")
    if not m_str: m_str = "10"
    if not n_str: n_str = "0"

    m = float(m_str)
    n = float(n_str)

    result = m / n
    print(f"Result: {result}")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Invalid input. Please enter numbers.")
# Out:
# Enter numerator (m):  sdfgh
# Enter denominator (n):  dfghjk
# Error: Invalid input. Please enter numbers.

# %% [markdown]
# Q2. Write a python program for following -
#       a) Create DataFrames Student 1, Student 2 and display contents
#       b) Merge two DataFrames in third frame .
#       c) Display contents of third DataFrame.
#                         Student 1                                       Student 2
#
#                    ID      Name          Age                     ID       City         Marks
#              0      S1     Anita            18               0     S2     Pune             97
#              1      S2     Sakshi           23               1     S4     Nashik           78
#              2      S3     Om               20               2     S5     Mumbai           86
#              3      S4     Raj              21               3     S6     Delhi            66
#              4      S5     Kanika           20               4     S7     Nanded           54
#
#                                                                                                 [20 Marks]

# %%
# Q2: DataFrames Student 1 and 2
data1 = {
    'ID': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'Name': ['Anita', 'Sakshi', 'Om', 'Raj', 'Kanika'],
    'Age': [18, 23, 20, 21, 20]
}
df1 = pd.DataFrame(data1)

data2 = {
    'ID': ['S2', 'S4', 'S5', 'S6', 'S7'],
    'City': ['Pune', 'Nashik', 'Mumbai', 'Delhi', 'Nanded'],
    'Marks': [97, 78, 86, 66, 54]
}
df2 = pd.DataFrame(data2)

df3 = pd.merge(df1, df2, on='ID', how='outer')

print("DataFrame Student 1:")
print(df1)
print("\nDataFrame Student 2:")
print(df2)
print("\nMerged DataFrame (Student 3):")
print(df3)
# Out:
# DataFrame Student 1:
#    ID    Name  Age
# 0  S1   Anita   18
# 1  S2  Sakshi   23
# 2  S3      Om   20
# 3  S4     Raj   21
# 4  S5  Kanika   20
#
# DataFrame Student 2:
#    ID    City  Marks
# 0  S2    Pune     97
# 1  S4  Nashik     78
# 2  S5  Mumbai     86
# 3  S6   Delhi     66
# 4  S7  Nanded     54
#
# Merged DataFrame (Student 3):
#    ID    Name   Age    City  Marks
# 0  S1   Anita  18.0     NaN    NaN
# 1  S2  Sakshi  23.0    Pune   97.0
# 2  S3      Om  20.0     NaN    NaN
# 3  S4     Raj  21.0  Nashik   78.0
# 4  S5  Kanika  20.0  Mumbai   86.0
# 5  S6     NaN   NaN   Delhi   66.0
# 6  S7     NaN   NaN  Nanded   54.0

# %% [markdown]
# ## OR
#
# OR
#
#
# Q2. Write a Python program to create a class that acts as an iterator and generates the factorial series up
#     to n (1! + 2! + 3! + … + n!). (Accept input from the user)

# %%
import math

class FactorialIterator:
    def __init__(self, n):
        self.n = n
        self.current = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.current > self.n:
            raise StopIteration
        val = math.factorial(self.current)
        self.current += 1
        return val

try:
    n_input = input("Enter n for factorial series: ")
    if not n_input: n_input = "5"
    n = int(n_input)
except ValueError:
    n = 5

iterator = FactorialIterator(n)
series_sum = 0
series_parts = []
for fact in iterator:
    series_parts.append(str(fact))
    series_sum += fact

print(f"\nGenerating factorial series up to {n}!")
print(f"Series: {' + '.join(series_parts)}")
print(f"Sum: {series_sum}")
# Out:
# Enter n for factorial series:  54
# Generating factorial series up to 54!
# Series: 1 + 2 + 6 + 24 + 120 + 720 + 5040 + 40320 + 362880 + 3628800 + 39916800 + 479001600 + 6227020800 + 87178291200 + 1307674368000 + 20922789888000 + 355687428096000 + 6402373705728000 + 121645100408832000 + 2432902008176640000 + 51090942171709440000 + 1124000727777607680000 + 25852016738884976640000 + 620448401733239439360000 + 15511210043330985984000000 + 403291461126605635584000000 + 10888869450418352160768000000 + 304888344611713860501504000000 + 8841761993739701954543616000000 + 265252859812191058636308480000000 + 8222838654177922817725562880000000 + 263130836933693530167218012160000000 + 8683317618811886495518194401280000000 + 295232799039604140847618609643520000000 + 10333147966386144929666651337523200000000 + 371993326789901217467999448150835200000000 + 13763753091226345046315979581580902400000000 + 523022617466601111760007224100074291200000000 + 20397882081197443358640281739902897356800000000 + 815915283247897734345611269596115894272000000000 + 33452526613163807108170062053440751665152000000000 + 1405006117752879898543142606244511569936384000000000 + 60415263063373835637355132068513997507264512000000000 + 2658271574788448768043625811014615890319638528000000000 + 119622220865480194561963161495657715064383733760000000000 + 5502622159812088949850305428800254892961651752960000000000 + 258623241511168180642964355153611979969197632389120000000000 + 12413915592536072670862289047373375038521486354677760000000000 + 608281864034267560872252163321295376887552831379210240000000000 + 30414093201713378043612608166064768844377641568960512000000000000 + 1551118753287382280224243016469303211063259720016986112000000000000 + 80658175170943878571660636856403766975289505440883277824000000000000 + 4274883284060025564298013753389399649690343788366813724672000000000000 + 230843697339241380472092742683027581083278564571807941132288000000000000
# Sum: 235200820952278866843442297568322826562475214315697749687568920420940313

# %% [markdown]
# Q3. Viva                                                                                       [5 Marks]
