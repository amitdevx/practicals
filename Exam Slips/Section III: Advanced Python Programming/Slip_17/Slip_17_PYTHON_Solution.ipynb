# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 17
# </h1>

# %% [markdown]
# ### 1.
#
# Q1. Write a Python program to list all files and folders in the current directory using os.listdir().
#                                                                                               [10 Marks]

# %%
import os
import re
import sys

print(f"Package structure created at {os.path.abspath(base_dir)}")

print(f"Current Directory: {current_dir}")

print("Contents:")

for num in test_numbers:
    if validate_mobile(num):
        print(f"'{num}' is a VALID mobile number.")
    else:
        print(f"'{num}' is INVALID.")

print("Subjects in Science:", science.get_subjects())
    print("Subjects in Arts:", arts.get_subjects())

except ImportError as e:
    print(f"Error importing package: {e}")
    print("Ensure you are running this script from the directory containing the 'education' package.")

# %% [markdown]
# Q2. Write a Python program to validate mobile number based on following criteria
#       a) The first digit should contain numbers between 6 to 9.
#       b) The rest 9 digit can contain any number between 0 to 9.
#       c) The mobile number can have 11 digits also by including 0 at the starting.
#       d) The mobile number can be of 12 digits also by including 91 at the starting
#                                                                                             [20 Marks]

# %%
def create_package_structure():
    base_dir = "education"
    sub_dir = os.path.join(base_dir, "courses")

os.makedirs(sub_dir, exist_ok=True)

open(os.path.join(base_dir, "__init__.py"), 'a').close()
    open(os.path.join(sub_dir, "__init__.py"), 'a').close()

with open(os.path.join(sub_dir, "science.py"), "w") as f:
        f.write("def get_subjects():\n    return ['Physics', 'Chemistry', 'Biology']")

with open(os.path.join(sub_dir, "arts.py"), "w") as f:
        f.write("def get_subjects():\n    return ['History', 'Geography', 'Political Science']")

current_dir = os.getcwd()

def validate_mobile(number):

# %% [markdown]
# ## OR
#
# OR
#
# Q2. Build a package education with a sub package courses, containing modules science.py and
#     arts.py. Each module should have a function get_subjects(). Write a python program to display all
#     subjects.

# %%
try:
    for entry in os.listdir(current_dir):
        print(entry)
except Exception as e:
    print(f"Error: {e}")

pattern = r"^(0|91)?[6-9]\d{9}$"

if re.match(pattern, number):
        return True
    return False

test_numbers = ["9876543210", "09876543210", "919876543210", "1234567890", "98765", "abcdefghij"]

create_package_structure()

sys.path.append(os.getcwd())

try:
    from education.courses import science, arts

# %% [markdown]
# Q3. Viva                                                                                    [5 Marks]
