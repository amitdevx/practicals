# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 18
# </h1>

# %%
import random
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.
#
# Q1. Write a Python program to shuffle a deck of card. Display the cards obtained by a user in 5
#     attempts.
#                                                                                           [10 Marks]

# %%
suits = ['Hearts', 'Diamonds', 'Clubs', 'Spades']

ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']

deck = [f"{rank} of {suit}" for suit in suits for rank in ranks]

print(f"Original Deck Size: {len(deck)}")

random.shuffle(deck)

print("Shuffled Deck. First 5 cards:")

for i in range(5):
    print(f"Card {i+1}: {deck[i]}")

current_dir = os.getcwd()

print(f"Current Directory: {current_dir}")

print("Original DataFrame:")

print(df)

print("\n-- a) Retrieve first 2 rows --")

print(df.head(2))

print("\n-- b) Retrieve last 3 rows --")

print(df.tail(3))

print("\n-- c) Check null values --")

print(df.isnull())

print("\nTotal Nulls per column:")

print(df.isnull().sum())

print("\n-- d) Replace null values with mean --")

print("DataFrame after filling nulls:")

print(df_filled)

print("\n-- e) Find most expensive player --")

print(f"Most Expensive Player: {expensive_player['Player']} with BidPrice {expensive_player['BidPrice']}")

print("\n-- f) Print total players per team --")

print(df['Team'].value_counts())

# %% [markdown]
# Q2. Write a python program to display all entries in a current directory and identify each as file or
#     folder. [Use getcwd() function to retrieve current directory]
#                                                                                             [20 Marks]

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ## OR
#
# OR
# Q2. Consider a following record in DataFrame IPL
#            Player        Team                        Category        BidPrice      Runs
#            Hardik Pandya Mumbai Indians              Batsman         null          1000
#
#            K L Rahul       Kings Eleven              Batsman         12            2400
#            Andre Russel    Kolkata Knight Riders     Batsman         7             900
#
#            Jasprit Bumrah Mumbai Indians             Bowler          10            null
#
#            Virat Kohli     RCB                       Batsman         null          3600
#            Rohit Sharma    Mumbai Indians            Batsman         15            3700
#
#        Create above DataFrame in python and write python code for following
#
#               a) Retrieve first 2 rows
#               b) Retrieve last 3 rows
#               c) Check null values in DataFrame.
#               d) Replace null values with mean of that column.
#               e) Find most expensive player.
#               f) Print total players per team.

# %%
try:
    entries = os.listdir(current_dir)
    for entry in entries:
        full_path = os.path.join(current_dir, entry)
        if os.path.isfile(full_path):
            print(f"[FILE]   {entry}")
        elif os.path.isdir(full_path):
            print(f"[FOLDER] {entry}")
        else:
            print(f"[OTHER]  {entry}")
except Exception as e:
    print(f"Error: {e}")

data = {
    'Player': ['Hardik Pandya', 'K L Rahul', 'Andre Russel', 'Jasprit Bumrah', 'Virat Kohli', 'Rohit Sharma'],
    'Team': ['Mumbai Indians', 'Kings Eleven', 'Kolkata Knight Riders', 'Mumbai Indians', 'RCB', 'Mumbai Indians'],
    'Category': ['Batsman', 'Batsman', 'Batsman', 'Bowler', 'Batsman', 'Batsman'],
    'BidPrice': [np.nan, 12, 7, 10, np.nan, 15],
    'Runs': [1000, 2400, 900, np.nan, 3600, 3700]
}

bid_mean = df['BidPrice'].mean()

runs_mean = df['Runs'].mean()

df_filled = df.copy()

df_filled['BidPrice'] = df['BidPrice'].fillna(bid_mean)

df_filled['Runs'] = df['Runs'].fillna(runs_mean)

max_price_idx = df_filled['BidPrice'].idxmax()

expensive_player = df_filled.loc[max_price_idx]

# %% [markdown]
# Q3. Viva                                                                                  [5 Marks]
