# %% [markdown]
# # Slip 24 - Advanced Python Programming

# %% [markdown]
# ## Q1. Write a python program to extract number from a given string and display extracted number.
#                                                                                         [10 Marks]

# %%
import re

text = "The price is $50, discount is $15, and total is $100."
numbers = re.findall(r'\d+', text)
print(f"Numbers extracted: {numbers}")
for num in numbers:
    print(num)
# Out:
# Numbers extracted: ['50', '15', '100']
# 50
# 15
# 100

# %% [markdown]
# ## Q2. Write a Python program that calculates the pass or fail status of multiple students.
#    a) Define a function check_pass_fail(marks) to return "Pass" if marks ≥ 40, otherwise "Fail".
#    b) Accept number of students and their marks.
#    c) Display each student’s result.
#    d) Print the total count of students who passed and failed.
#                                                                                            [20 Marks]

# %%
def check_pass_fail(marks):
    return "Pass" if marks >= 40 else "Fail"

# Demo data (instead of input() which doesn't work in notebooks)
student_data = {
    "Alice": 85,
    "Bob": 35,
    "Charlie": 40,
    "David": 22,
    "Eve": 95
}

pass_count = 0
fail_count = 0
results = {}

for name, marks in student_data.items():
    result = check_pass_fail(marks)
    results[name] = result
    if result == "Pass":
        pass_count += 1
    else:
        fail_count += 1

print("Student Results:")
for name, result in results.items():
    print(f"{name}: {result}")

print(f"\nTotal Passed: {pass_count}")
print(f"Total Failed: {fail_count}")
# Out:
# Student Results:
# Alice: Pass
# Bob: Fail
# Charlie: Pass
# David: Fail
# Eve: Pass
#
# Total Passed: 3
# Total Failed: 2

# %% [markdown]
# ## OR

# %% [markdown]
# ## Q2. Create a Web Page using Flask which contains following information about your college.
#     a) College Name as a heading in center of web page.
#     b) Display all the courses available in your college.
#     c) Image of your College.

# %% [markdown]
# **Note:** This Flask application cannot run inside a Jupyter notebook.
#
# See the complete Flask project in the [`slip_24/`](slip_24/) folder:
# - **Q1 (main):** [`slip_24/slip_24_Q1/`](slip_24/slip_24_Q1/)
# - **Q2 (OR):** [`slip_24/slip_24_Q2/`](slip_24/slip_24_Q2/)
#
# To run: `cd slip_24/slip_24_Q2/Q2 && python Q24_app2.py`

# %% [markdown]
# ## Q3. Viva
#
# [5 Marks]
#
# Viva Voce / 5 Marks.
