# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 19
# </h1>

# %%
import os
import pandas as pd

# %% [markdown]
# ### 1.
#
# Q1. Write a python program to accept a string, Count total number of vowels, consonants and special
#     symbols from it.
#                                                                                              [10 Marks]

# %%
try:
    text = input("Enter a string: ")
except EOFError:
    text = "Hello World! @2023"
    print(f"Input: {text}")

vowels = 0

consonants = 0

symbols = 0

v_set = set("aeiouAEIOU")

for char in text:
    if char.isalpha():
        if char in v_set:
            vowels += 1
        else:
            consonants += 1
    elif not char.isspace(): # Count spaces as symbols? Usually special symbols means non-alphanumeric.
        symbols += 1

print(f"Vowels: {vowels}")

print(f"Consonants: {consonants}")

print(f"Special Symbols (non-alpha): {symbols}")

filename = "test_file_slip19.txt"

with open(filename, "w") as f:
    f.write("This is a sample file content for testing file pointer operations.")

print(f"Created dummy file '{filename}' with content: 'This is a sample file content for testing file pointer operations.'")

try:
    fname = input("Enter filename (default: test_file_slip19.txt): ")
    if not fname: fname = filename

pos_str = input("Enter byte position: ")
    if not pos_str: pos_str = "10"
    position = int(pos_str)

if os.path.exists(fname):
        with open(fname, 'r') as f:
            f.seek(position)
            content = f.read()
            print(f"\nContent from byte {position}:")
            print(content)
    else:
        print("File does not exist.")

print("DataFrame:")

print(df)

print(f"\nType of GroupBy object: {type(grouped)}")

print("\nStats of age per school:")

print(grouped['age'].agg(['mean', 'min', 'max']))

print(f"\nNumber of students with weight > 32: {count}")

# %% [markdown]
# Q2. Write a Python program to accept a file name and a byte position as input. If file exist open a file in
#     read mode and move the file pointer to the given byte position, prints the content of the file from
#     that position till end of file otherwise give appropriate message.
#                                                                                             [20 Marks]

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ## OR
#
# OR
#
#
# Q2. Create a Pandas DataFrame using the following student data with columns and perform the
#     following tasks:
#            school   class    name     date_of_birth    age   height   weight    address
#            S1       S001    Asha      15/05/2002       12    173      35        Street1
#            S2       S002    Fransis   17/05/2002       12    192      32        Street2
#            S3       S003    Charlie   16/02/1999       13    186      33        Street3
#            S4       S004    David     25/09/1998       14    167      30        Street4
#            S5       S005    Shyam     11/05/2002       12    151      31        Street5
#            S6       S006    Eashel    15/09/1997       16    159      32        Street6
#
#      a) Split the DataFrame into groups based on the school column using the GroupBy operation.
#      b) Check and display the type of the GroupBy object created.
#      c) Calculate the mean, minimum, and maximum values of the age column for each school group.
#      d) Count the number of students whose weight is greater than 32.

# %%
except Exception as e:
    print(f"Error: {e}")

if os.path.exists(filename):
    os.remove(filename)

data = {
    'school': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'class': ['S001', 'S002', 'S003', 'S004', 'S005', 'S006'],
    'name': ['Asha', 'Fransis', 'Charlie', 'David', 'Shyam', 'Eashel'],
    'date_of_birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 14, 12, 16],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['Street1', 'Street2', 'Street3', 'Street4', 'Street5', 'Street6']
}

grouped = df.groupby('school')

count = df[df['weight'] > 32].shape[0]

# %% [markdown]
# Q3. Viva                                                                                    [5 Marks]
