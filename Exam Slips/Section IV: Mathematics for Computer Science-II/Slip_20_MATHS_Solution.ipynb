# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Slip 20
# </h1>

# %% [markdown]
# ## Q1. Attempt any four of the following.

# %% [markdown]
# ### 1.
#
# Draw a pie chart for the given data with radius 0.7 , show percentage :
#
# | Subject | Number of students |
# | --- | --- |
# | History | 168 |
# | Geography | 90 |
# | English | 195 |
# | Sociology | 95 |
# | Psychology | 46 |

# %%
import matplotlib.pyplot as plt

subjects = ['History', 'Geography', 'English', 'Sociology', 'Psychology']
counts = [168, 90, 195, 95, 46]

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(counts, labels=subjects, autopct='%1.1f%%', startangle=90, radius=0.7)
ax.set_title('Preference of Subjects (Radius = 0.7)')
ax.axis('equal')
plt.show()

# %% [markdown]
# ### 2.
#
# Plot the graph of x2 + 5x in [5, 10] with dotted pattern.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(5, 10, 200)
y = x**2 + 5 * x

plt.figure(figsize=(8, 4))
plt.plot(x, y, ':', color='black', linewidth=2)
plt.title(r'Plot of $y = x^2 + 5x$ for $5 \leq x \leq 10$')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, linestyle=':')
plt.show()

# %% [markdown]
# ### 3.
#
# Using sympy declare points A (1 ,1) , B( 1, 6), C (6 ,1) , D( 6, 6) and plot quadrilateral
# ABCD in
#
# black color.

# %%
import matplotlib.pyplot as plt
from sympy import Point

A = Point(1, 1)
B = Point(1, 6)
C = Point(6, 1)
D = Point(6, 6)

points = [A, B, D, C, A]
xs = [pt.x for pt in points]
ys = [pt.y for pt in points]

plt.figure(figsize=(6, 6))
plt.plot(xs, ys, color='black', marker='o')
plt.title('Quadrilateral ABCD')
plt.xlabel('x')
plt.ylabel('y')
plt.gca().set_aspect('equal', 'box')
plt.grid(True, linestyle=':')
plt.show()

# %% [markdown]
# ### 4.
#
# Using sympy declare quadrilateral ABCD where A (1 ,1), B(1, 4), C( 4, 1) and D(4, 4),
# and find shearing of ABCD in x and y directions by 3 and 7 units respectively

# %%
from sympy import Point, Matrix

A = Point(1, 1)
B = Point(1, 4)
C = Point(4, 1)
D = Point(4, 4)
points = [A, B, C, D]

shear_x = Matrix([[1, 3], [0, 1]])
shear_y = Matrix([[1, 0], [7, 1]])

def apply(matrix, point):
    vec = matrix * Matrix(point)
    return Point(vec[0], vec[1])

sheared_x = [apply(shear_x, pt) for pt in points]
sheared_y = [apply(shear_y, pt) for pt in points]

print('Shear in x-direction (k = 3):')
for label, pt in zip(['A'', 'B'', 'C'', 'D''], sheared_x):
    print(f'  {label}: {pt}')

print('Shear in y-direction (k = 7):')
for label, pt in zip(['A"', 'B"', 'C"', 'D"'], sheared_y):
    print(f'  {label}: {pt}')

# %% [markdown]
# ### 5.
#
# If the line segment joining the points A[−3, 5] and B[3, 3] is transformed to the line segment
# 𝟏
# A’B’ by the transformation matrix [T] =[
# 𝟒
#
# 𝟑
# ],then using sympy find the midpoint of the
# 𝟏
#
# transformed line.

# %%
from sympy import Point, Matrix

A = Point(-3, 5)
B = Point(3, 3)
T = Matrix([[1/4, 3], [1, 1]])

def transform(point):
    vec = T * Matrix(point)
    return Point(vec[0], vec[1])

A_prime = transform(A)
B_prime = transform(B)
midpoint = Point((A_prime.x + B_prime.x) / 2, (A_prime.y + B_prime.y) / 2)

print(f'A' transformed: {A_prime}')
print(f'B' transformed: {B_prime}')
print(f'Midpoint of A'B': {midpoint}')

# %% [markdown]
# ### Q2.1 (Attempt Any One)
#
# 1. Write a python program to plot the triangle with vertices at (4,4) , (2, 4) ,( 4, 2) .
# 𝜋
# Apply the transformations a) its rotation about the origin by radians, b) uniform scaling
# 2
# by factor 3. Plot original and transformed figures in different colours
# Also plot x and y
# axes in one colour.

# %%
import numpy as np
import matplotlib.pyplot as plt

triangle = np.array([[4, 4], [2, 4], [4, 2]], dtype=float)
closed_original = np.vstack([triangle, triangle[0]])

theta = np.pi / 2
rotation = np.array([[np.cos(theta), -np.sin(theta)],
                     [np.sin(theta), np.cos(theta)]])
rotated = (rotation @ triangle.T).T
closed_rotated = np.vstack([rotated, rotated[0]])

scaled = triangle * 3
closed_scaled = np.vstack([scaled, scaled[0]])

plt.figure(figsize=(6, 6))
plt.plot(closed_original[:, 0], closed_original[:, 1], color='blue', marker='o', label='Original Triangle')
plt.plot(closed_rotated[:, 0], closed_rotated[:, 1], color='red', marker='s', label='Rotated $90^\circ$')
plt.plot(closed_scaled[:, 0], closed_scaled[:, 1], color='green', marker='^', label='Uniform Scale x3')

plt.axhline(0, color='black', linewidth=0.8, label='Axes')
plt.axvline(0, color='black', linewidth=0.8)
plt.gca().set_aspect('equal', 'box')
plt.title('Transformations of Triangle')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True, linestyle=':')
plt.show()

# %% [markdown]
# ### OR

# %% [markdown]
# ### Q2.2
#
# 2. Write Python program to generate and plot 100 points on parabola y2 = 32 x ,
# iterative formulae for 0  x  100.

# %%
import matplotlib.pyplot as plt

num_points = 100
max_x = 100
step = max_x / (num_points - 1)

xs = []
ys = []
x_val = 0.0
for _ in range(num_points):
    y_val = (32 * x_val) ** 0.5
    xs.append(x_val)
    ys.append(y_val)
    x_val += step

plt.figure(figsize=(7, 4))
plt.scatter(xs, ys, color='purple', label=r'$y^2 = 32x$')
plt.title('Points on Parabola $y^2 = 32x$ for $0 \leq x \leq 100$')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, linestyle=':')
plt.legend()
plt.show()

# %% [markdown]
# Q.3. Viva Voce .
#
# –––––––––––––––
#
# [5 Marks ]
#
# * –––––––––––––––
#
# using
