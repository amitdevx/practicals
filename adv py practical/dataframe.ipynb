# %%
import pandas as pd
 
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18],
        'test':[23,54,45,78]}
 
df = pd.DataFrame(data)
 
print(df)
# Out:
#     Name  Age  test
# 0    Tom   20    23
# 1   nick   21    54
# 2  krish   19    45
# 3   jack   18    78

# %%
import pandas as pd
 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
df = pd.DataFrame(data)
 
print(df[['Name', 'Qualification','Age']])
# Out:
#      Name Qualification  Age
# 0     Jai           Msc   27
# 1  Princi            MA   24
# 2  Gaurav           MCA   22
# 3    Anuj           Phd   32

# %%
import pandas as pd
 
data = pd.read_csv("nba.csv", index_col="Name")
second = data.loc["25"]
 
print("\n\n\n", second)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/jupyter-env/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '25'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
# ...

# %%
import pandas as pd
 
data = pd.read_csv("nba.csv", index_col ="Name")

first = data["Age"]
 
print(first)
# Out:
# Name
# Avery Bradley    25.0
# Jae Crowder      25.0
# John Holland     27.0
# R.J. Hunter      22.0
# Jonas Jerebko    29.0
#                  ...
# Shelvin Mack     26.0
# Raul Neto        24.0
# Tibor Pleiss     26.0
# Jeff Withey      26.0
# NaN               NaN
# Name: Age, Length: 458, dtype: float64

# %%
import pandas as pd
std_data=[(1,'varun',24,'male','nashik'),
           (2,'ravi',19,'male','dehli'),
           (3,'preeto',24,'female','jaipur'),
           (4,'amit',20,'male','banglore'),
           (5,'pinki',25,'female','mumbai')]
df=pd.DataFrame(std_data,columns=['stud_id','name','age','gender','city'])
df
# Out:
#    stud_id    name  age  gender      city
# 0        1   varun   24    male    nashik
# 1        2    ravi   19    male     dehli
# 2        3  preeto   24  female    jaipur
# 3        4    amit   20    male  banglore
# 4        5   pinki   25  female    mumbai

# %%
df=pd.read_csv("student.csv")
df
# Out:
#    index column1  age    name
# 0      1      fg    3    amit
# 1      2      fg    5    ravi
# 2      3     sfg    8   anmol
# 3      4     sfg    5  sunder
# 4      5    sdfg    5   rashi
# 5      6     sfg    5  maheer
# 6      7     sfg    7   aryan
# 7      8      fg    8    yash

# %%
df.head(2)
# Out:
#   lk;ll  dfg    sfg
# 0    fg  fgs   fdgs
# 1    fg  fgs  dfgsd

# %%
df.tail(1)
# Out:
#   lk;ll  dfg  sfg
# 7    fg  fgs  NaN

# %%
df.shape
# Out:
# (8, 3)

# %%
df.columns
# Out:
# Index(['lk;ll', 'dfg', 'sfg'], dtype='object')

# %%
df['dfg']
# Out:
# 0     fgs
# 1     fgs
# 2    sfgs
# 3    sfgs
# 4    sfgs
# 5    sfgs
# 6    sfgs
# 7     fgs
# Name: dfg, dtype: object

# %%
df.size
# Out:
# 24

# %%
df.dtypes
# Out:
# lk;ll    object
# dfg      object
# sfg      object
# dtype: object

# %%
df.values
# Out:
# array([['fg', 3, 'amit'],
#        ['fg', 5, 'ravi'],
#        ['sfg', 8, 'anmol'],
#        ['sfg', 5, 'sunder'],
#        ['sdfg', 5, 'rashi'],
#        ['sfg', 5, 'maheer'],
#        ['sfg', 7, 'aryan'],
#        ['fg', 8, 'yash']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %% [markdown]
# # selecting row and column

# %%
df['age']
# Out:
# 0    3
# 1    5
# 2    8
# 3    5
# 4    5
# 5    5
# 6    7
# 7    8
# Name: age, dtype: int64

# %% [markdown]
# # row by indexm

# %%
df.loc[1]
# Out:
# column1      fg
# age           5
# name       ravi
# Name: 1, dtype: object

# %%
df.iloc[2]
# Out:
# column1      sfg
# age            8
# name       anmol
# Name: 2, dtype: object

# %%
df.iloc[[0,7]]
# Out:
#    index column1  age  name
# 0      1      fg    3  amit
# 7      8      fg    8  yash

# %% [markdown]
# # filtering rowm

# %%
df[df['age'] > 3]
# Out:
#    index column1  age    name
# 1      2      fg    5    ravi
# 2      3     sfg    8   anmol
# 3      4     sfg    5  sunder
# 4      5    sdfg    5   rashi
# 5      6     sfg    5  maheer
# 6      7     sfg    7   aryan
# 7      8      fg    8    yash

# %% [markdown]
# # adding a new column

# %%
df['phone_no']=[10,20,30,40,50,60,70,80]
df
# Out:
#    index column1  age    name  phone_no
# 0      1      fg    3    amit        10
# 1      2      fg    5    ravi        20
# 2      3     sfg    8   anmol        30
# 3      4     sfg    5  sunder        40
# 4      5    sdfg    5   rashi        50
# 5      6     sfg    5  maheer        60
# 6      7     sfg    7   aryan        70
# 7      8      fg    8    yash        80

# %%
df.insert(3,'phone_no',[10,20,30,40,50,60,70,80])
print(df)
# Out:
#    index column1  student_age  phone_no    name
# 0      1      fg            3        10    amit
# 1      2      fg            5        20    ravi
# 2      3     sfg            8        30   anmol
# 3      4     sfg            5        40  sunder
# 4      5    sdfg            5        50   rashi
# 5      6     sfg            5        60  maheer
# 6      7     sfg            7        70   aryan
# 7      8      fg            8        80    yash

# %%
df = df.drop(columns=['phone_no'])
df 
#delete
# Out:
#    index column1  student_age    name
# 0      1      fg            3    amit
# 1      2      fg            5    ravi
# 2      3     sfg            8   anmol
# 3      4     sfg            5  sunder
# 4      5    sdfg            5   rashi
# 5      6     sfg            5  maheer
# 6      7     sfg            7   aryan
# 7      8      fg            8    yash

# %%
df=df.rename(columns={'age':'student_age'})
df #rename
# Out:
#    index column1  student_age    name
# 0      1      fg            3    amit
# 1      2      fg            5    ravi
# 2      3     sfg            8   anmol
# 3      4     sfg            5  sunder
# 4      5    sdfg            5   rashi
# 5      6     sfg            5  maheer
# 6      7     sfg            7   aryan
# 7      8      fg            8    yash

# %%
del df['phone_no']
df
# Out:
#    index column1  student_age    name
# 0      1      fg            3    amit
# 1      2      fg            5    ravi
# 2      3     sfg            8   anmol
# 3      4     sfg            5  sunder
# 4      5    sdfg            5   rashi
# 5      6     sfg            5  maheer
# 6      7     sfg            7   aryan
# 7      8      fg            8    yash

# %%
df = df.drop(3)
df
# Out:
#    index column1  student_age    name
# 0      1      fg            3    amit
# 1      2      fg            5    ravi
# 4      5    sdfg            5   rashi
# 5      6     sfg            5  maheer
# 6      7     sfg            7   aryan
# 7      8      fg            8    yash

# %%
df.loc[4] = [4,'dg',6,'pinki']

# %%
df
# Out:
#    index column1  age    name
# 0      1      fg    3    amit
# 1      2      fg    5    ravi
# 2      3     sfg    8   anmol
# 3      4     sfg    5  sunder
# 4      4      dg    6   pinki
# 5      6     sfg    5  maheer
# 6      7     sfg    7   aryan
# 7      8      fg    8    yash

# %%
df.loc[2,'age']=8
df
# Out:
#    index column1  age    name
# 0      1      fg    3    amit
# 1      2      fg    5    ravi
# 2      3     sfg    8   anmol
# 3      4     sfg    5  sunder
# 4      4      dg    6   pinki
# 5      6     sfg    5  maheer
# 6      7     sfg    7   aryan
# 7      8      fg    8    yash

# %% [markdown]
# # updating multiple value

# %%
df.loc[[0,2],'age']=89
df
# Out:
#    index column1  age    name
# 0      1      fg   89    amit
# 1      2      fg    5    ravi
# 2      3     sfg   89   anmol
# 3      4     sfg    5  sunder
# 4      4      dg    6   pinki
# 5      6     sfg    5  maheer
# 6      7     sfg    7   aryan
# 7      8      fg    8    yash
