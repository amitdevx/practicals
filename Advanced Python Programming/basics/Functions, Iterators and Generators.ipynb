# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Assignment 2:
# </h1>

# %% [markdown]
# # Title: Functions, Iterators and Generators

# %%
print("coming")
# Out:
# coming
