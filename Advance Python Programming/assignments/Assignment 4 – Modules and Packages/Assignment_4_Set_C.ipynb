# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Assignment 4: Set C
# </h1>

# %% [markdown]
# # Modules and Packages - Set C

# %% [markdown]
# ## Q1. Create a package named library with a sub package books, containing modules fiction and nonfiction.
#
# package: `Set_C/library/books/`

# %%
import sys
sys.path.insert(0, 'Set_C')

from library.books import fiction, nonfiction

print("Fiction:", fiction.list_books())
print("Non-Fiction:", nonfiction.list_books())
# Out:
# Fiction: ['Harry Potter', 'The Lord of the Rings', 'The Great Gatsby', '1984']
# Non-Fiction: ['Sapiens', 'Atomic Habits', 'Rich Dad Poor Dad']

# %% [markdown]
# ## Q2. Create a package finance_tools with modules interest.py and currency.py.
#
# package: `Set_C/finance_tools/`

# %%
from finance_tools import interest, currency

print("Simple Interest:", interest.simple_interest(10000, 8, 5))
print("Compound Interest:", round(interest.compound_interest(10000, 8, 5), 2))
print("10000 INR to USD:", round(currency.inr_to_usd(10000), 2))
print("100 USD to INR:", currency.usd_to_inr(100))
# Out:
# Simple Interest: 4000.0
# Compound Interest: 4693.28
# 10000 INR to USD: 119.05
# 100 USD to INR: 8400

# %% [markdown]
# ## Q3. Case Study: Food Delivery App
#
# package: `Set_C/food_delivery/system/`

# %%
from food_delivery.system import restaurants, orders, agents

print("Restaurants:", restaurants.list_restaurants())
orders.place_order("Pizza Palace", ["Pizza", "Coke"])
agents.assign_agent()
# Out:
# Restaurants: ['Pizza Palace', 'Burger Barn', 'Spice Garden']
# Order placed at Pizza Palace
# Items: ['Pizza', 'Coke']
# Agent Rahul assigned for delivery

# %% [markdown]
# ## Q4. Case Study: Travel Agency System
#
# package: `Set_C/travel_agency/packages/`

# %%
from travel_agency.packages import domestic, international

print("Domestic:", domestic.get_packages())
print("International:", international.get_packages())

domestic.book_package("Goa")
international.book_package("Dubai")
# Out:
# Domestic: ['Goa', 'Kerala', 'Rajasthan']
# International: ['Dubai', 'Singapore', 'Thailand']
# Booked: Goa
# Booked: Dubai
