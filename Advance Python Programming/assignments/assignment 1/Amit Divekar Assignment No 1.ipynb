# %% [markdown]
# <h1 style="text-align:center;">
#   <a href="https://amitdevx.tech" style="color:red; font-weight:bold; text-decoration:none;">
#     Amit Divekar
#   </a>
#   | Assignment 1:
# </h1>

# %% [markdown]
# <h1 style="color:red; font-weight:bold; text-align:center;">DataFrame</h1>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
